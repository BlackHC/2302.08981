# %% [markdown]
# # Applying Deep Batch Active Learning to your own learning task

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# In this notebook, we show how our implemented batch mode deep active learning (BMDAL) methods can be applied to a custom NN. We will first change the working directory from the examples subfolder to the main folder, which is required for the imports to work correctly.

# %%
import os
os.chdir('../..')   # change directory inside the notebook to the main directory

# %%
# !pwd
# Out:
# /home/blackhc/PycharmProjects/bmdal_reg

# %% [markdown]
# ## Example with artificial data and custom model

# %% [markdown]
# We first generate some artificial 2-D training data, which will be plotted below.

# %%
import torch
import torch.nn as nn

n_train = 100
n_pool = 2000
torch.manual_seed(1234)
x = torch.randn(n_train+n_pool, 3)
theta = 3*(x[:, 1] + 0.1 * x[:, 0])
x = (0.2 * x[:, 2] + x[:, 1] + 2)[:, None] * torch.stack([torch.sin(theta), torch.cos(theta)], dim=1)
y = torch.exp(x[:, 0])
y = y[:, None]

x_train = x[:n_train]
y_train = y[:n_train]
x_pool = x[n_train:]
y_pool = y[n_train:]

# %% [markdown]
# Note that for the labels, we have used the deterministic function $y = e^{x_1}$. In order to learn this function, it would be better to have more training points on the right of the domain. We can visualize the pool set (in gray) and the train set (in black) without the labels as follows:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(x_pool[:, 0].numpy(), x_pool[:, 1].numpy(), '.', color='#BBBBBB')
plt.plot(x_train[:, 0].numpy(), x_train[:, 1].numpy(), '.', color='k')
plt.show()

# %% [markdown]
# Next, we train a NN on the given training data. For this, we use a simple three-layer NN using the standard layers from PyTorch. Since we only have 100 training points, we use all of the data in each step. We optimize the NN using Adam for 256 epochs with fixed learning rate. These hyperparameters are only an example, you may use other values.

# %%
custom_models = []

for _ in range(5):
    custom_model = nn.Sequential(nn.Linear(2, 100), nn.SiLU(), nn.Linear(100, 100), nn.SiLU(), nn.Linear(100, 1))
    opt = torch.optim.Adam(custom_model.parameters(), lr=2e-2)
    for epoch in range(256):
        y_pred = custom_model(x_train)
        loss = ((y_pred - y_train)**2).mean()
        train_rmse = loss.sqrt().item()
        pool_rmse = ((custom_model(x_pool) - y_pool)**2).mean().sqrt().item()
        print(f'train RMSE: {train_rmse:5.3f}, pool RMSE: {pool_rmse:5.3f}')
        loss.backward()
        opt.step()
        opt.zero_grad()

    custom_models.append(custom_model)
# Out:
# train RMSE: 5.334, pool RMSE: 7.043
# train RMSE: 4.116, pool RMSE: 6.060
# train RMSE: 2.640, pool RMSE: 4.933
# train RMSE: 2.833, pool RMSE: 4.774
# train RMSE: 2.589, pool RMSE: 4.797
# train RMSE: 1.809, pool RMSE: 4.461
# train RMSE: 1.725, pool RMSE: 4.376
# train RMSE: 1.956, pool RMSE: 4.430
# train RMSE: 1.917, pool RMSE: 4.374
# train RMSE: 1.600, pool RMSE: 4.187
# train RMSE: 1.261, pool RMSE: 3.989
# train RMSE: 1.320, pool RMSE: 3.916
# train RMSE: 1.594, pool RMSE: 3.940
# train RMSE: 1.584, pool RMSE: 3.909
# train RMSE: 1.325, pool RMSE: 3.840
# train RMSE: 1.161, pool RMSE: 3.844
# train RMSE: 1.234, pool RMSE: 3.919
# train RMSE: 1.332, pool RMSE: 3.976
# train RMSE: 1.303, pool RMSE: 3.960
# train RMSE: 1.151, pool RMSE: 3.882
# train RMSE: 0.988, pool RMSE: 3.794
# train RMSE: 0.122, pool RMSE: 3.032
# train RMSE: 0.128, pool RMSE: 3.029
# train RMSE: 0.146, pool RMSE: 3.025
# train RMSE: 0.177, pool RMSE: 3.028
# train RMSE: 0.194, pool RMSE: 3.026
# train RMSE: 0.160, pool RMSE: 3.025
# train RMSE: 0.110, pool RMSE: 3.018
# train RMSE: 0.149, pool RMSE: 3.015
# train RMSE: 0.162, pool RMSE: 3.015
# train RMSE: 0.113, pool RMSE: 3.011
# train RMSE: 0.127, pool RMSE: 3.011
# train RMSE: 0.149, pool RMSE: 3.011
# train RMSE: 0.109, pool RMSE: 3.005
# train RMSE: 0.119, pool RMSE: 3.001
# train RMSE: 0.136, pool RMSE: 3.000
# train RMSE: 0.103, pool RMSE: 2.996
# train RMSE: 0.115, pool RMSE: 2.995
# train RMSE: 0.124, pool RMSE: 2.993
# train RMSE: 0.098, pool RMSE: 2.988
# train RMSE: 0.112, pool RMSE: 2.985
# train RMSE: 0.114, pool RMSE: 2.984
# train RMSE: 0.094, pool RMSE: 2.981
# train RMSE: 0.109, pool RMSE: 2.980
# train RMSE: 0.106, pool RMSE: 2.977
# train RMSE: 0.092, pool RMSE: 2.973
# train RMSE: 0.104, pool RMSE: 2.971
# train RMSE: 0.099, pool RMSE: 2.969
# train RMSE: 0.090, pool RMSE: 2.967
# train RMSE: 0.100, pool RMSE: 2.965
# train RMSE: 0.094, pool RMSE: 2.963
# train RMSE: 0.088, pool RMSE: 2.960
# train RMSE: 0.095, pool RMSE: 2.958
# train RMSE: 0.090, pool RMSE: 2.956
# train RMSE: 0.085, pool RMSE: 2.954
# train RMSE: 0.091, pool RMSE: 2.952
# train RMSE: 0.087, pool RMSE: 2.949
# train RMSE: 0.083, pool RMSE: 2.947
# train RMSE: 0.087, pool RMSE: 2.945
# train RMSE: 0.084, pool RMSE: 2.944
# train RMSE: 0.080, pool RMSE: 2.942
# train RMSE: 0.083, pool RMSE: 2.939
# train RMSE: 0.082, pool RMSE: 2.937
# train RMSE: 0.078, pool RMSE: 2.935
# train RMSE: 0.079, pool RMSE: 2.934
# train RMSE: 0.080, pool RMSE: 2.932
# train RMSE: 0.076, pool RMSE: 2.929
# train RMSE: 0.076, pool RMSE: 2.927
# train RMSE: 0.077, pool RMSE: 2.925
# train RMSE: 0.075, pool RMSE: 2.924
# train RMSE: 0.073, pool RMSE: 2.922
# train RMSE: 0.074, pool RMSE: 2.920
# train RMSE: 0.074, pool RMSE: 2.918
# train RMSE: 0.072, pool RMSE: 2.916
# train RMSE: 0.071, pool RMSE: 2.914
# train RMSE: 0.072, pool RMSE: 2.913
# train RMSE: 0.071, pool RMSE: 2.911
# train RMSE: 0.069, pool RMSE: 2.909
# train RMSE: 0.069, pool RMSE: 2.907
# train RMSE: 0.069, pool RMSE: 2.905
# train RMSE: 0.068, pool RMSE: 2.904
# train RMSE: 0.067, pool RMSE: 2.902
# train RMSE: 0.067, pool RMSE: 2.900
# train RMSE: 0.067, pool RMSE: 2.898
# train RMSE: 0.066, pool RMSE: 2.897
# train RMSE: 0.065, pool RMSE: 2.895
# train RMSE: 0.064, pool RMSE: 2.893
# train RMSE: 0.064, pool RMSE: 2.892
# train RMSE: 0.064, pool RMSE: 2.890
# train RMSE: 0.063, pool RMSE: 2.888
# train RMSE: 0.062, pool RMSE: 2.887
# train RMSE: 0.062, pool RMSE: 2.885
# train RMSE: 0.062, pool RMSE: 2.883
# train RMSE: 0.061, pool RMSE: 2.882
# train RMSE: 0.060, pool RMSE: 2.880
# train RMSE: 0.060, pool RMSE: 2.879
# train RMSE: 0.060, pool RMSE: 2.877
# train RMSE: 0.059, pool RMSE: 2.876
# train RMSE: 0.059, pool RMSE: 2.874
# train RMSE: 0.058, pool RMSE: 2.873
# train RMSE: 0.058, pool RMSE: 2.871
# train RMSE: 0.057, pool RMSE: 2.870
# train RMSE: 0.057, pool RMSE: 2.868
# train RMSE: 0.057, pool RMSE: 2.867
# train RMSE: 0.056, pool RMSE: 2.866
# train RMSE: 0.056, pool RMSE: 2.864
# train RMSE: 0.055, pool RMSE: 2.863
# train RMSE: 0.055, pool RMSE: 2.861
# train RMSE: 0.055, pool RMSE: 2.860
# train RMSE: 0.054, pool RMSE: 2.859
# train RMSE: 0.054, pool RMSE: 2.857
# train RMSE: 0.054, pool RMSE: 2.856
# train RMSE: 0.053, pool RMSE: 2.854
# train RMSE: 0.053, pool RMSE: 2.853
# train RMSE: 0.052, pool RMSE: 2.852
# train RMSE: 0.052, pool RMSE: 2.851
# train RMSE: 0.052, pool RMSE: 2.849
# train RMSE: 0.051, pool RMSE: 2.848
# train RMSE: 0.051, pool RMSE: 2.847
# train RMSE: 0.051, pool RMSE: 2.845
# train RMSE: 0.050, pool RMSE: 2.844
# train RMSE: 0.050, pool RMSE: 2.843
# train RMSE: 0.050, pool RMSE: 2.842
# train RMSE: 0.050, pool RMSE: 2.841
# train RMSE: 0.050, pool RMSE: 2.839
# train RMSE: 0.050, pool RMSE: 2.838
# train RMSE: 0.050, pool RMSE: 2.837
# train RMSE: 0.052, pool RMSE: 2.836
# train RMSE: 0.056, pool RMSE: 2.835
# train RMSE: 0.063, pool RMSE: 2.834
# train RMSE: 0.076, pool RMSE: 2.833
# train RMSE: 0.098, pool RMSE: 2.833
# train RMSE: 0.128, pool RMSE: 2.833
# train RMSE: 0.163, pool RMSE: 2.834
# train RMSE: 0.177, pool RMSE: 2.833
# train RMSE: 0.153, pool RMSE: 2.832
# train RMSE: 0.078, pool RMSE: 2.827
# train RMSE: 0.060, pool RMSE: 2.826
# train RMSE: 0.121, pool RMSE: 2.827
# train RMSE: 0.125, pool RMSE: 2.826
# train RMSE: 0.072, pool RMSE: 2.824
# train RMSE: 0.056, pool RMSE: 2.823
# train RMSE: 0.103, pool RMSE: 2.823
# train RMSE: 0.097, pool RMSE: 2.822
# train RMSE: 0.049, pool RMSE: 2.819
# train RMSE: 0.069, pool RMSE: 2.819
# train RMSE: 0.093, pool RMSE: 2.819
# train RMSE: 0.065, pool RMSE: 2.817
# train RMSE: 0.047, pool RMSE: 2.816
# train RMSE: 0.077, pool RMSE: 2.816
# train RMSE: 0.071, pool RMSE: 2.814
# train RMSE: 0.043, pool RMSE: 2.813
# train RMSE: 0.108, pool RMSE: 3.005
# train RMSE: 0.107, pool RMSE: 3.003
# train RMSE: 0.105, pool RMSE: 3.000
# train RMSE: 0.104, pool RMSE: 2.996
# train RMSE: 0.103, pool RMSE: 2.993
# train RMSE: 0.101, pool RMSE: 2.992
# train RMSE: 0.100, pool RMSE: 2.990
# train RMSE: 0.099, pool RMSE: 2.987
# train RMSE: 0.097, pool RMSE: 2.983
# train RMSE: 0.096, pool RMSE: 2.980
# train RMSE: 0.095, pool RMSE: 2.979
# train RMSE: 0.094, pool RMSE: 2.978
# train RMSE: 0.093, pool RMSE: 2.975
# train RMSE: 0.092, pool RMSE: 2.972
# train RMSE: 0.091, pool RMSE: 2.969
# train RMSE: 0.090, pool RMSE: 2.968
# train RMSE: 0.089, pool RMSE: 2.966
# train RMSE: 0.088, pool RMSE: 2.964
# train RMSE: 0.087, pool RMSE: 2.960
# train RMSE: 0.086, pool RMSE: 2.958
# train RMSE: 0.085, pool RMSE: 2.957
# train RMSE: 0.085, pool RMSE: 2.955
# train RMSE: 0.085, pool RMSE: 2.953
# train RMSE: 0.087, pool RMSE: 2.950
# train RMSE: 0.094, pool RMSE: 2.949
# train RMSE: 0.112, pool RMSE: 2.948
# train RMSE: 0.140, pool RMSE: 2.949
# train RMSE: 0.157, pool RMSE: 2.946
# train RMSE: 0.128, pool RMSE: 2.944
# train RMSE: 0.078, pool RMSE: 2.939
# train RMSE: 0.110, pool RMSE: 2.939
# train RMSE: 0.129, pool RMSE: 2.940
# train RMSE: 0.089, pool RMSE: 2.935
# train RMSE: 0.087, pool RMSE: 2.933
# train RMSE: 0.115, pool RMSE: 2.934
# train RMSE: 0.090, pool RMSE: 2.930
# train RMSE: 0.078, pool RMSE: 2.929
# train RMSE: 0.104, pool RMSE: 2.929
# train RMSE: 0.086, pool RMSE: 2.925
# train RMSE: 0.075, pool RMSE: 2.924
# train RMSE: 0.095, pool RMSE: 2.924
# train RMSE: 0.081, pool RMSE: 2.921
# train RMSE: 0.072, pool RMSE: 2.919
# train RMSE: 0.088, pool RMSE: 2.919
# train RMSE: 0.076, pool RMSE: 2.916
# train RMSE: 0.070, pool RMSE: 2.915
# train RMSE: 0.082, pool RMSE: 2.915
# train RMSE: 0.073, pool RMSE: 2.912
# train RMSE: 0.068, pool RMSE: 2.910
# train RMSE: 0.077, pool RMSE: 2.910
# train RMSE: 0.070, pool RMSE: 2.908
# train RMSE: 0.066, pool RMSE: 2.906
# train RMSE: 0.073, pool RMSE: 2.906
# train RMSE: 0.068, pool RMSE: 2.903
# train RMSE: 0.064, pool RMSE: 2.902
# train RMSE: 0.069, pool RMSE: 2.902
# train RMSE: 0.066, pool RMSE: 2.899
# train RMSE: 0.062, pool RMSE: 2.898
# train RMSE: 0.065, pool RMSE: 2.897
# train RMSE: 0.064, pool RMSE: 2.895
# train RMSE: 0.060, pool RMSE: 2.894
# train RMSE: 0.062, pool RMSE: 2.893
# train RMSE: 0.063, pool RMSE: 2.891
# train RMSE: 0.059, pool RMSE: 2.890
# train RMSE: 0.059, pool RMSE: 2.889
# train RMSE: 0.060, pool RMSE: 2.887
# train RMSE: 0.058, pool RMSE: 2.886
# train RMSE: 0.057, pool RMSE: 2.885
# train RMSE: 0.058, pool RMSE: 2.883
# train RMSE: 0.057, pool RMSE: 2.883
# train RMSE: 0.055, pool RMSE: 2.881
# train RMSE: 0.055, pool RMSE: 2.880
# train RMSE: 0.056, pool RMSE: 2.879
# train RMSE: 0.054, pool RMSE: 2.877
# train RMSE: 0.053, pool RMSE: 2.876
# train RMSE: 0.053, pool RMSE: 2.875
# train RMSE: 0.053, pool RMSE: 2.874
# train RMSE: 0.052, pool RMSE: 2.873
# train RMSE: 0.051, pool RMSE: 2.871
# train RMSE: 0.051, pool RMSE: 2.870
# train RMSE: 0.051, pool RMSE: 2.869
# train RMSE: 0.050, pool RMSE: 2.868
# train RMSE: 0.049, pool RMSE: 2.867
# train RMSE: 0.049, pool RMSE: 2.866
# train RMSE: 0.049, pool RMSE: 2.864
# train RMSE: 0.049, pool RMSE: 2.864
# train RMSE: 0.048, pool RMSE: 2.862
# train RMSE: 0.047, pool RMSE: 2.861
# train RMSE: 0.047, pool RMSE: 2.860
# train RMSE: 0.047, pool RMSE: 2.859
# train RMSE: 0.046, pool RMSE: 2.858
# train RMSE: 0.046, pool RMSE: 2.857
# train RMSE: 0.045, pool RMSE: 2.856
# train RMSE: 0.045, pool RMSE: 2.855
# train RMSE: 0.045, pool RMSE: 2.854
# train RMSE: 0.044, pool RMSE: 2.853
# train RMSE: 0.044, pool RMSE: 2.852
# train RMSE: 0.043, pool RMSE: 2.851
# train RMSE: 0.043, pool RMSE: 2.850
# train RMSE: 0.043, pool RMSE: 2.849
# train RMSE: 0.042, pool RMSE: 2.848
# train RMSE: 0.042, pool RMSE: 2.847
# train RMSE: 0.041, pool RMSE: 2.846
# train RMSE: 0.041, pool RMSE: 2.845
# train RMSE: 0.041, pool RMSE: 2.844
# train RMSE: 0.041, pool RMSE: 2.843
# train RMSE: 0.040, pool RMSE: 2.842
# train RMSE: 0.040, pool RMSE: 2.841
# train RMSE: 0.040, pool RMSE: 2.840
# train RMSE: 0.039, pool RMSE: 2.840
# train RMSE: 0.039, pool RMSE: 2.839
# train RMSE: 0.038, pool RMSE: 2.838
# train RMSE: 0.038, pool RMSE: 2.837
# train RMSE: 0.038, pool RMSE: 2.836
# train RMSE: 0.038, pool RMSE: 2.835
# train RMSE: 0.037, pool RMSE: 2.834
# train RMSE: 0.037, pool RMSE: 2.833
# train RMSE: 0.037, pool RMSE: 2.833
# train RMSE: 0.037, pool RMSE: 2.832
# train RMSE: 0.036, pool RMSE: 2.831
# train RMSE: 0.036, pool RMSE: 2.830
# train RMSE: 0.036, pool RMSE: 2.829
# train RMSE: 0.036, pool RMSE: 2.829
# train RMSE: 0.036, pool RMSE: 2.828
# train RMSE: 0.036, pool RMSE: 2.827
# train RMSE: 0.037, pool RMSE: 2.826
# train RMSE: 0.039, pool RMSE: 2.826
# train RMSE: 0.043, pool RMSE: 2.824
# train RMSE: 0.050, pool RMSE: 2.825
# train RMSE: 0.062, pool RMSE: 2.823
# train RMSE: 0.080, pool RMSE: 2.825
# train RMSE: 0.105, pool RMSE: 2.822
# train RMSE: 0.130, pool RMSE: 2.827
# train RMSE: 0.143, pool RMSE: 2.821
# train RMSE: 0.125, pool RMSE: 2.826
# train RMSE: 0.072, pool RMSE: 2.818
# train RMSE: 0.034, pool RMSE: 2.819
# train RMSE: 0.082, pool RMSE: 2.822
# train RMSE: 0.105, pool RMSE: 2.816
# train RMSE: 0.081, pool RMSE: 2.821
# train RMSE: 0.034, pool RMSE: 2.816
# train RMSE: 0.058, pool RMSE: 2.815
# train RMSE: 0.084, pool RMSE: 2.820
# train RMSE: 0.069, pool RMSE: 2.814
# train RMSE: 0.033, pool RMSE: 2.815
# train RMSE: 0.051, pool RMSE: 2.816
# train RMSE: 0.070, pool RMSE: 2.812
# train RMSE: 0.055, pool RMSE: 2.816
# train RMSE: 0.031, pool RMSE: 2.813

# %% [markdown]
# Next, we want to select 50 new points to label using Deep Batch Active Learning. For this, we wrap our training and pool inputs in the `TensorFeatureData` class and call the method `bmdal.algorithms.select_batch()` method with the batch size (50), our trained model, training and pool data as well as our desired configuration of selection method, mode (`sel_with_train`), base kernel and kernel transformations. Here, we use the LCMD-TP method proposed in our paper. For an extensive overview over the available options, we refer to the docstring in the code for `bmdal.algorithms.select_batch()`. Finally, we plot the selected samples from the pool set.
#
# Note: If your training / pool data is so large that it does not fit on the device (CPU/GPU), you may need to write a custom `FeatureData` subclass, where the `get_tensor_impl_()` method acts as a data loader. Please contact the library author in this case. If the data does not fit into the GPU RAM but does fit into CPU RAM, you can also pass `al_on_cpu=True` to `ModelTrainer` to run active learning on the CPU.
#
# The function `select_batch()` supports the computation of gradient features for layers of type `nn.Linear` by default. In order to support gradients for other types of layers, there are two options:
# - The first option is that the other layers inherit from `bmdal.layer_features.LayerGradientComputation` and implement the corresponding methods. For example, the class `bmdal.layer_features.LinearLayer` does this. In contrast to `nn.Linear`, it supports the factors $\sigma_w/\sqrt{d_l}$ and $\sigma_b$ from the paper, and it is used in our benchmarking code.
# - The second option is that a matching of the other layer types to corresponding subclasses of `bmdal.layer_features.LayerGradientComputation` is provided via the `layer_grad_dict` argument of `select_batch()`. For more details, we refer to the documentation of `select_batch()`.

# %%
from bmdal_reg.bmdal.feature_data import TensorFeatureData
from bmdal_reg.bmdal.algorithms import select_batch

train_data = TensorFeatureData(x_train)
pool_data = TensorFeatureData(x_pool)
new_idxs, _ = select_batch(batch_size=50, models=custom_models[:2], 
                           data={'train': train_data, 'pool': pool_data}, y_train=y_train,
                           selection_method='lcmd', sel_with_train=False,
                           base_kernel='predictions', kernel_transforms=[]) #[('rp', [5])])

plt.plot(x_pool[:, 0].numpy(), x_pool[:, 1].numpy(), '.', color='#BBBBBB')
plt.plot(x_train[:, 0].numpy(), x_train[:, 1].numpy(), '.', color='k')
plt.plot(x_pool[new_idxs, 0].numpy(), x_pool[new_idxs, 1].numpy(), '.', color='b')
plt.show()
# Out:
# torch.Size([2, 100, 1])
# torch.Size([2, 2000, 1])
# filling up with random samples because selection failed after n_selected = 2

# %%
from bmdal_reg.bmdal.feature_data import TensorFeatureData
from bmdal_reg.bmdal.algorithms import select_batch

train_data = TensorFeatureData(x_train)
pool_data = TensorFeatureData(x_pool)
new_idxs, _ = select_batch(batch_size=50, models=custom_models, 
                           data={'train': train_data, 'pool': pool_data}, y_train=y_train,
                           selection_method='lcmd', sel_with_train=False,
                           base_kernel='grad', kernel_transforms=[('rp', [512]), ('ens', [])])

plt.plot(x_pool[:, 0].numpy(), x_pool[:, 1].numpy(), '.', color='#BBBBBB')
plt.plot(x_train[:, 0].numpy(), x_train[:, 1].numpy(), '.', color='k')
plt.plot(x_pool[new_idxs, 0].numpy(), x_pool[new_idxs, 1].numpy(), '.', color='b')
plt.show()

# %% [markdown]
# We can observe that the BMDAL method selected more pool samples from the right of the domain. This is desirable since the target function is $y = e^{x_1}$, which is steeper at the right of the domain. This behavior would not arise from a network-independent base kernel like 'linear', 'nngp' or 'laplace'.

# %% [markdown]
# ## Example using our benchmark data and training code

# %% [markdown]
# In the following, we will give a different example, utilizing a data set from our benchmark and our functions for creating and fitting fully-connected NN models. The code is adapted from `ModelTrainer.__call__()` in `train.py`. First, we need to choose a data set. We choose the `road_network` data set since it contains 2D inputs representing locations in north Denmark, which can be nicely visualized. We choose an initial training set size of `n_train=256`. The argument `al_batch_sizes` is not relevant to us here since we will choose the batch size manually later. We then create a random split of the task with `id=0`, which also serves as a random seed for the split. Finally, we convert the index tensor for the respective parts of the data set to PyTorch tensors.
#
# To be able to run the following code, it is required to follow the data download instructions from the README.md file in the repository.

# %%
from bmdal_reg.data import Task, TaskSplit
import torch

task = Task.get_tabular_tasks(n_train=256, al_batch_sizes=[256] * 16, ds_names=['road_network'])[0]
task_split = TaskSplit(task, id=0)
train_idxs = torch.as_tensor(task_split.train_idxs, dtype=torch.int64)
valid_idxs = torch.as_tensor(task_split.valid_idxs, dtype=torch.int64)
pool_idxs = torch.as_tensor(task_split.pool_idxs, dtype=torch.int64)
test_idxs = torch.as_tensor(task_split.test_idxs, dtype=torch.int64)
data = task_split.data

# %% [markdown]
# Now, we visualize the pool points (gray) and training points (black). The shape of north Denmark can clearly be recognized.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x_train = data.tensors['X'][train_idxs]
x_pool = data.tensors['X'][pool_idxs]
y_pool = data.tensors['y'][pool_idxs]
plt.plot(x_pool[:, 0].numpy(), x_pool[:, 1].numpy(), '.', color='#BBBBBB')
plt.plot(x_train[:, 0].numpy(), x_train[:, 1].numpy(), '.', color='k')
plt.show()

# %% [markdown]
# Next, we create a fully-connected NN model with NTK Parametrization using the function `create_tabular_model` and train it using `fit_model`. Both functions contain more optional arguments to modify hyperparameters like the width and number of layers, the learning rate, and so on. We refer to the respective implementations for more details.
#
# Unlike typical PyTorch code, the two functions mentioned above work with NNs that are vectorized such that multiple ensemble members are trained separately. The number of ensemble members is given by the `n_models` parameter, which we set to $1$. In order to obtain a non-vectorized NN in the end, which is required for BMDAL, we call the function `get_single_model()`.

# %%
from bmdal_reg.train import fit_model
from bmdal_reg.models import create_tabular_model

n_models = 5
n_features = data.tensors['X'].shape[1]  # will be 2 in our case
vectorized_model = create_tabular_model(n_models=n_models, n_features=n_features)
fit_model(vectorized_model, data, n_models, train_idxs, valid_idxs)
# Out:
# ................................................................................................................................................................................................................................................................

# %%
vectorized_model
# Out:
# ParallelSequential(
#   (layers): ModuleList(
#     (0): ParallelLinearLayer()
#     (1): ParallelLayerWrapper(
#       (module): ReLU()
#     )
#     (2): ParallelLinearLayer()
#     (3): ParallelLayerWrapper(
#       (module): ReLU()
#     )
#     (4): ParallelLinearLayer()
#   )
# )

# %% [markdown]
# The model structure, printed below, contains some custom layer types. The `ParallelSequential` and `ParallelLayerWrapper` layers come from the vectorization, but for the purpose of BMDAL `ParallelSequential` could be replaced by `nn.Sequential` and `ParallelLayerWrapper` could be omitted. The class `bmdal.layer_features.LinearLayer` implements the abstract class `bmdal.layer_features.LayerGradientComputation` and is therefore automatically used for computing gradient features. Compared to `nn.Linear`, `LinearLayer` supports weight and bias factors $\sigma_w/\sqrt{d_l}$ and $\sigma_b$ from the Neural Tangent Parameterization as used in the paper.

# %%
print(vectorized_model[0],len(vectorized_model))
# Out:
# ParallelSequential(
#   (layers): ModuleList(
#     (0): LinearLayer()
#     (1): ParallelLayerWrapper(
#       (module): ReLU()
#     )
#     (2): LinearLayer()
#     (3): ParallelLayerWrapper(
#       (module): ReLU()
#     )
#     (4): LinearLayer()
#   )
# ) 5

# %% [markdown]
# Now, we apply BMDAL to select a subset of elements from the pool set as in the example above.

# %%
from bmdal_reg.bmdal.feature_data import TensorFeatureData
from bmdal_reg.bmdal.algorithms import select_batch

X = TensorFeatureData(data.tensors['X'])
feature_data = {'train': X[train_idxs],
                'pool': X[pool_idxs]}
y_train = data.tensors['y'][train_idxs]
new_idxs, al_stats = select_batch(batch_size=128, models=vectorized_model, data=feature_data, y_train=y_train,
                                  selection_method='maxdet', sel_with_train=False, maxdet_sigma=0.1,
                                  base_kernel='predictions', kernel_transforms=[]) #=[('rp', [512])])

# move new_idxs from the pool set to the training set
# therefore, we first create a boolean array that is True at the indices in new_idxs and False elsewhere
logical_new_idxs = torch.zeros(pool_idxs.shape[-1], dtype=torch.bool)
logical_new_idxs[new_idxs] = True
# We now append the new indices to the training set
train_idxs = torch.cat([train_idxs, pool_idxs[logical_new_idxs]], dim=-1)
# and remove them from the pool set
pool_idxs = pool_idxs[~logical_new_idxs]

# %% [markdown]
# The `al_stats` object contains some information about the execution of BMDAL. Here, the time for building the features and running the selection was about 19 seconds on a CPU, which is not very much considering that the initial pool set contains 198,720 samples! The entry for `selection_status` may contain a warning message in case that the normal selection failed. Usually, the batch is filled up with random samples in this case. Here, we have no warning.

# %%
print(al_stats)
# Out:
# {'kernel_time': {'total': 2.048780713001179, 'process': 47.398274028}, 'selection_time': {'total': 0.2860658659992623, 'process': 6.803763821999951}, 'selection_status': None}

# %% [markdown]
# Next, we plot the selected points:

# %%
plt.plot(x_pool[:, 0].numpy(), x_pool[:, 1].numpy(), '.', color='#BBBBBB')
plt.plot(x_train[:, 0].numpy(), x_train[:, 1].numpy(), '.', color='k')
plt.plot(x_pool[new_idxs, 0].numpy(), x_pool[new_idxs, 1].numpy(), '.', color='b')
plt.show()

# %% [markdown]
# The selected points concentrate in some regions of the space. We can see that the labels (which correspond to the elevation of the land in this data set) vary more strongly in these regions:

# %%
plt.scatter(x_pool[:, 0].numpy(), x_pool[:, 1].numpy(), c=y_pool[:, 0].numpy())
plt.gray()
plt.show()
